# %%
import scoring_functions as fn

# %% [markdown]
# #### Operation ID vs temp and top_p
#
# Test the effect of changing temperature and top_p on the quality of generated operation IDs for use with an OpenAPI spec

# %%
scenario = "Generate OpenAPI operation ID (getCalendarForUser)"
split_response = True
prompt_template = """
    For the specified request, generate an operation ID, compatible with an
    OpenAPI spec. Respond with just the ID in plain-text format. For example,
    for request such as `GET https://api.contoso.com/books/{{books-id}}` you
    return `getBook`. For a request like
    `GET https://api.contoso.com/books/{{books-id}}/authors` you return `getAuthorsForBook`. Request:
    {request}
    """.strip()
tasks = [
    {
        "name": "default temp and top_p",
        "reference_texts": [
            "getCalendarForUser",
            "fetchUserCalendar",
            "getUserCalendar"
        ],
        "prompt": prompt_template.format(request="GET https://graph.microsoft.com/users/{{users-id}}/calendars/{{calendars-id}}")
    },
    {
        "name": "temp: 0",
        "reference_texts": [
            "getCalendarForUser",
            "fetchUserCalendar",
            "getUserCalendar"
        ],
        "prompt": prompt_template.format(request="GET https://graph.microsoft.com/users/{{users-id}}/calendars/{{calendars-id}}"),
        "temperature": 0
    },
    {
        "name": "temp: 0.5",
        "reference_texts": [
            "getCalendarForUser",
            "fetchUserCalendar",
            "getUserCalendar"
        ],
        "prompt": prompt_template.format(request="GET https://graph.microsoft.com/users/{{users-id}}/calendars/{{calendars-id}}"),
        "temperature": 0.5
    },
    {
        "name": "temp: 1",
        "reference_texts": [
            "getCalendarForUser",
            "fetchUserCalendar",
            "getUserCalendar"
        ],
        "prompt": prompt_template.format(request="GET https://graph.microsoft.com/users/{{users-id}}/calendars/{{calendars-id}}"),
        "temperature": 1
    },
    {
        "name": "temp: 2",
        "reference_texts": [
            "getCalendarForUser",
            "fetchUserCalendar",
            "getUserCalendar"
        ],
        "prompt": prompt_template.format(request="GET https://graph.microsoft.com/users/{{users-id}}/calendars/{{calendars-id}}"),
        "temperature": 2
    },
    {
        "name": "top_p: 0",
        "reference_texts": [
            "getCalendarForUser",
            "fetchUserCalendar",
            "getUserCalendar"
        ],
        "prompt": prompt_template.format(request="GET https://graph.microsoft.com/users/{{users-id}}/calendars/{{calendars-id}}"),
        "top_p": 0
    },
    {
        "name": "top_p: 0.5",
        "reference_texts": [
            "getCalendarForUser",
            "fetchUserCalendar",
            "getUserCalendar"
        ],
        "prompt": prompt_template.format(request="GET https://graph.microsoft.com/users/{{users-id}}/calendars/{{calendars-id}}"),
        "top_p": 0.5
    },
    {
        "name": "top_p: 1",
        "reference_texts": [
            "getCalendarForUser",
            "fetchUserCalendar",
            "getUserCalendar"
        ],
        "prompt": prompt_template.format(request="GET https://graph.microsoft.com/users/{{users-id}}/calendars/{{calendars-id}}"),
        "top_p": 1
    }
]
score_threshold = 0.8
metric_scorers = [
    {
        'name': 'BERT-F',
        'fn': fn.calculate_bert_f,
        'weight': 0.45
    },
    {
        'name': 'Edit distance',
        'fn': fn.calculate_edit_distance,
        'weight': 0.1
    },
    {
        'name': 'ROUGE-1',
        'fn': fn.calculate_rouge1,
        'weight': 0.25
    },
    {
        'name': 'ROUGE-L',
        'fn': fn.calculate_rougeL,
        'weight': 0.2
    }
]
